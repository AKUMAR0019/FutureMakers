# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn import metrics

import os

# %%
tf.compat.v1.reset_default_graph()
tf.compat.v1.disable_eager_execution()
INPUT_SIGNAL_TYPES = [
    "body_acc_x_",
    "body_acc_y_",
    "body_acc_z_",
    "body_gyro_x_",
    "body_gyro_y_",
    "body_gyro_z_",
    "total_acc_x_",
    "total_acc_y_",
    "total_acc_z_",
]

LABELS = [
    "WALKING",
    "WALKING_UPSTAIRS",
    "WALKING_DOWNSTAIRS",
    "SITTING",
    "STANDYING",
    "LAYING"
]

# %%
DATASET_PATH = "./UCI HAR Dataset/"
TRAIN = "train/"
TEST = "test/"

def load_X(X_signals_paths):
    X_signals = []
    
    for signal_type_path in X_signals_paths:
        file = open(signal_type_path, 'r')
        X_signals.append(
        [np.array(serie,dtype=np.float32) for serie in [
            row.replace('  ', ' ').strip().split(' ') for row in file
            ]]
        )
        file.close()
        
        return np.transpose(np.array(X_signals), (1,2,0))
X_train_signals_paths = [
    DATASET_PATH + TRAIN + "Inertial Signals/" + signal + "train.txt" for signal in INPUT_SIGNAL_TYPES
]
X_test_signals_paths = [
    DATASET_PATH + TEST + "Inertial Signals/" + signal + "test.txt" for signal in INPUT_SIGNAL_TYPES
]

X_train = load_X(X_train_signals_paths)
X_test = load_X(X_test_signals_paths)

def load_y(y_path):
    file = open(y_path, 'r')
    y = np.array(
    [elem for elem in [
        row.replace('  ', ' ').strip().split(' ') for row in file
    ]],
    dtype = np.int32
    )
    file.close()
    
    return y - 1
y_train_path = DATASET_PATH + TRAIN + "y_train.txt"
y_test_path = DATASET_PATH + TEST + "y_test.txt"

y_train = load_y(y_train_path)
y_test = load_y(y_test_path)

# %%
training_data_count = len(X_train)
test_data_count = len(X_test)
n_steps = len(X_train[0])
n_input = len(X_train[0][0])

n_hidden = 32
n_classes = 6

learning_rate = 0.00225
lambda_loss_amount = 0.0015
training_iters = training_data_count * 300
batch_size = 1500
display_iter = 30000

print("Some useful info to get an insight on dataset's shape and normalization:")
print("(X shape, y shape, every X's mean, every X's standard deviation)")
print(X_test.shape, y_test.shape, np.mean(X_test), np.std(X_test))
print("The dataset is therefore properly normalized, as expected, but not yet one-hot encoded.")
# Out:
# Some useful info to get an insight on dataset's shape and normalization:
# (X shape, y shape, every X's mean, every X's standard deviation)
# (2947, 128, 1) (2947, 1) -0.00073775335 0.18430972
# The dataset is therefore properly normalized, as expected, but not yet one-hot encoded.

# %%
def LSTM_RNN(_X, _weights, _biases):
    _X = tf.transpose(_X, [1,0,2])
    _X = tf.reshape(_X, [-1, n_input])
    _X = tf.nn.relu(tf.matmul(_X, _weights['hidden']) + _biases['hidden'])
    _X = tf.split(_X, n_steps, 0)
    
    lstm_cell_1 = tf.compat.v1.nn.rnn_cell.LSTMCell(n_hidden, forget_bias=1.0, state_is_tuple=True)
    lstm_cell_2 = tf.compat.v1.nn.rnn_cell.LSTMCell(n_hidden, forget_bias=1.0, state_is_tuple=True)
    lstm_cells = tf.compat.v1.nn.rnn_cell.MultiRNNCell([lstm_cell_1, lstm_cell_2], state_is_tuple = True)
    
    outputs, states = tf.compat.v1.nn.static_rnn(lstm_cells, _X, dtype = tf.float32)
    
    lstm_last_output = outputs[-1]
    
    return tf.matmul(lstm_last_output, _weights['out']) + _biases['out']

def extract_batch_size(_train, step, batch_size):
    shape = list(_train.shape)
    shape[0] = batch_size
    batch_s = np.empty(shape)
    
    for i in range(batch_size):
        index = ((step-1)*batch_size + i) % len(_train)
        batch_s[i] = _train[index]
    
    return batch_s
def one_hot(y_, n_classes=n_classes):
    y_ = y_.reshape(len(y_))
    return np.eye(n_classes)[np.array(y_, dtype=np.int32)]

# %%
x = tf.compat.v1.placeholder(tf.float32, [None, n_steps, n_input])
y = tf.compat.v1.placeholder(tf.float32, [None, n_classes])

weights = {
    'hidden': tf.Variable(tf.compat.v1.random_normal([n_input, n_hidden])),
    'out': tf.Variable(tf.compat.v1.random_normal([n_hidden, n_classes], mean=1.0))    
}
biases = {
    'hidden': tf.Variable(tf.compat.v1.random_normal([n_hidden])),
    'out': tf.Variable(tf.compat.v1.random_normal([n_classes]))
}

pred = LSTM_RNN(x, weights, biases)

l2 = lambda_loss_amount * sum(
    tf.nn.l2_loss(tf_var) for tf_var in tf.compat.v1.trainable_variables()
)
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=pred)) + l2

optimizer = tf.compat.v1.train.AdamOptimizer(learning_rate=learning_rate).minimize(cost)

correct_pred = tf.equal(tf.argmax(pred,1), tf.argmax(y,1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))
# Out:
# WARNING:tensorflow:`tf.nn.rnn_cell.MultiRNNCell` is deprecated. This class is equivalent as `tf.keras.layers.StackedRNNCells`, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From <ipython-input-5-918b064dc734>:11: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /Users/Ashu/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:987: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /Users/Ashu/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/layers/legacy_rnn/rnn_cell_impl.py:909: UserWarning: `tf.nn.rnn_cell.LSTMCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.LSTMCell`, and will be replaced by that in Tensorflow 2.0.
#   warnings.warn("`tf.nn.rnn_cell.LSTMCell` is deprecated and will be "
# /Users/Ashu/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer_v1.py:1700: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '

# %%
test_losses = []
test_accuracies = []
train_losses = []
train_accuracies = []

sess = tf.compat.v1.InteractiveSession(config=tf.compat.v1.ConfigProto(log_device_placement=True))
init = tf.compat.v1.global_variables_initializer()
sess.run(init)

step = 1
while step * batch_size <= training_iters:
    batch_xs = extract_batch_size(X_train, step, batch_size)
    batch_ys = one_hot(extract_batch_size(y_train, step, batch_size))
    
    _, loss, acc = sess.run(
    [optimizer,cost,accuracy],
    feed_dict={
        x:batch_xs,
        y:batch_ys
    }
    )
    train_losses.append(loss)
    train_accuracies.append(acc)
    
    if(step*batch_size % display_iter == 0) or (step == 1) or (step * batch_size > training_iters):
        print("Training iter #" + str(step*batch_size) + ":   Batch Loss = " + "{:.6f}".format(loss) + ", Accuracy = {}".format(acc))
        loss, acc = sess.run(
        [cost, accuracy],
        feed_dict={
            x: X_test,
            y: one_hot(y_test)
        })
        
        test_losses.append(loss)
        test_accuracies.append(acc)
        print("PERFORMANCE ON TEST SET: " + "Batch Loss = {}".format(loss) + ", Accuracy = {}".format(acc))
    step += 1
print("Optimization Finished!")

one_hot_predictions, accuracy, final_loss = sess.run(
    [pred, accuracy, cost],
    feed_dict={
        x: X_test,
        y: one_hot(y_test)
    }
)

test_losses.append(final_loss)
test_accuracies.append(accuracy)
print("FINAL RESULT: " + "Batch Loss = {}".format(final_loss) + ", Accuracy = {}".format(accuracy))
# Out:
# Device mapping: no known devices.
# Training iter #1500:   Batch Loss = 2.538385, Accuracy = 0.1653333306312561
# PERFORMANCE ON TEST SET: Batch Loss = 2.3306527137756348, Accuracy = 0.18221920728683472
# Training iter #30000:   Batch Loss = 2.080471, Accuracy = 0.2293333262205124
# PERFORMANCE ON TEST SET: Batch Loss = 2.050248622894287, Accuracy = 0.238547682762146
# Training iter #60000:   Batch Loss = 3.308194, Accuracy = 0.19333332777023315
# PERFORMANCE ON TEST SET: Batch Loss = 3.1300387382507324, Accuracy = 0.1944350153207779
# Training iter #90000:   Batch Loss = 1.880077, Accuracy = 0.19200000166893005
# PERFORMANCE ON TEST SET: Batch Loss = 1.9373046159744263, Accuracy = 0.297251433134079
# Training iter #120000:   Batch Loss = 1.557879, Accuracy = 0.3880000114440918
# PERFORMANCE ON TEST SET: Batch Loss = 1.5561811923980713, Accuracy = 0.34882932901382446
# Training iter #150000:   Batch Loss = 1.436847, Accuracy = 0.40666666626930237
# PERFORMANCE ON TEST SET: Batch Loss = 1.4525463581085205, Accuracy = 0.41024771332740784
# Training iter #180000:   Batch Loss = 1.331728, Accuracy = 0.49266666173934937
# PERFORMANCE ON TEST SET: Batch Loss = 1.399541974067688, Accuracy = 0.433322012424469
# Training iter #210000:   Batch Loss = 1.320883, Accuracy = 0.4753333330154419
# PERFORMANCE ON TEST SET: Batch Loss = 1.3672125339508057, Accuracy = 0.45469969511032104
# Training iter #240000:   Batch Loss = 1.317046, Accuracy = 0.5006666779518127
# PERFORMANCE ON TEST SET: Batch Loss = 1.4043594598770142, Accuracy = 0.4302680790424347
# Training iter #270000:   Batch Loss = 1.369557, Accuracy = 0.4560000002384186
# PERFORMANCE ON TEST SET: Batch Loss = 1.3009593486785889, Accuracy = 0.5005089640617371
# Training iter #300000:   Batch Loss = 1.350254, Accuracy = 0.5346666574478149
# PERFORMANCE ON TEST SET: Batch Loss = 1.231224775314331, Accuracy = 0.5327451825141907
# Training iter #330000:   Batch Loss = 1.482883, Accuracy = 0.437333345413208
# PERFORMANCE ON TEST SET: Batch Loss = 1.369507074356079, Accuracy = 0.45402103662490845
# Training iter #360000:   Batch Loss = 1.143021, Accuracy = 0.5820000171661377
# PERFORMANCE ON TEST SET: Batch Loss = 1.2563631534576416, Accuracy = 0.5144214630126953
# Training iter #390000:   Batch Loss = 1.124086, Accuracy = 0.6033333539962769
# PERFORMANCE ON TEST SET: Batch Loss = 1.1561532020568848, Accuracy = 0.57550048828125
# Training iter #420000:   Batch Loss = 1.139211, Accuracy = 0.5759999752044678
# PERFORMANCE ON TEST SET: Batch Loss = 1.2192745208740234, Accuracy = 0.5310485363006592
# Training iter #450000:   Batch Loss = 1.108098, Accuracy = 0.6140000224113464
# PERFORMANCE ON TEST SET: Batch Loss = 1.1883609294891357, Accuracy = 0.5656599998474121
# Training iter #480000:   Batch Loss = 1.122970, Accuracy = 0.5613333582878113
# PERFORMANCE ON TEST SET: Batch Loss = 1.1381511688232422, Accuracy = 0.5697319507598877
# Training iter #510000:   Batch Loss = 1.162642, Accuracy = 0.5706666707992554
# PERFORMANCE ON TEST SET: Batch Loss = 1.2138689756393433, Accuracy = 0.5581947565078735
# Training iter #540000:   Batch Loss = 1.246303, Accuracy = 0.5379999876022339
# PERFORMANCE ON TEST SET: Batch Loss = 1.1301465034484863, Accuracy = 0.5778757929801941
# Training iter #570000:   Batch Loss = 1.119344, Accuracy = 0.5640000104904175
# PERFORMANCE ON TEST SET: Batch Loss = 1.1268503665924072, Accuracy = 0.5907703042030334
# Training iter #600000:   Batch Loss = 1.103970, Accuracy = 0.559333324432373
# PERFORMANCE ON TEST SET: Batch Loss = 1.09657621383667, Accuracy = 0.5870376825332642
# Training iter #630000:   Batch Loss = 1.094638, Accuracy = 0.5693333148956299
# PERFORMANCE ON TEST SET: Batch Loss = 1.1020534038543701, Accuracy = 0.5839837193489075
# Training iter #660000:   Batch Loss = 1.133169, Accuracy = 0.5613333582878113
# PERFORMANCE ON TEST SET: Batch Loss = 1.099602222442627, Accuracy = 0.5843230485916138
# Training iter #690000:   Batch Loss = 1.066520, Accuracy = 0.5839999914169312
# PERFORMANCE ON TEST SET: Batch Loss = 1.0755891799926758, Accuracy = 0.5863590240478516
# Training iter #720000:   Batch Loss = 1.005188, Accuracy = 0.6326666474342346
# PERFORMANCE ON TEST SET: Batch Loss = 1.077528715133667, Accuracy = 0.609093964099884
# Training iter #750000:   Batch Loss = 0.962384, Accuracy = 0.624666690826416
# PERFORMANCE ON TEST SET: Batch Loss = 1.0917327404022217, Accuracy = 0.594502866268158
# Training iter #780000:   Batch Loss = 0.906549, Accuracy = 0.668666660785675
# PERFORMANCE ON TEST SET: Batch Loss = 1.0831365585327148, Accuracy = 0.585680365562439
# Training iter #810000:   Batch Loss = 0.906986, Accuracy = 0.6573333144187927
# PERFORMANCE ON TEST SET: Batch Loss = 1.0603439807891846, Accuracy = 0.5887343287467957
# Training iter #840000:   Batch Loss = 0.969810, Accuracy = 0.656000018119812
# PERFORMANCE ON TEST SET: Batch Loss = 1.087152123451233, Accuracy = 0.6080760359764099
# Training iter #870000:   Batch Loss = 1.018400, Accuracy = 0.5953333377838135
# PERFORMANCE ON TEST SET: Batch Loss = 1.0519633293151855, Accuracy = 0.5924668908119202
# Training iter #900000:   Batch Loss = 0.927669, Accuracy = 0.6346666812896729
# PERFORMANCE ON TEST SET: Batch Loss = 1.0544222593307495, Accuracy = 0.589073657989502
# Training iter #930000:   Batch Loss = 1.004173, Accuracy = 0.5799999833106995
# PERFORMANCE ON TEST SET: Batch Loss = 1.077943205833435, Accuracy = 0.5843230485916138
# Training iter #960000:   Batch Loss = 0.989395, Accuracy = 0.6186666488647461
# PERFORMANCE ON TEST SET: Batch Loss = 1.0556209087371826, Accuracy = 0.5982354879379272
# Training iter #990000:   Batch Loss = 1.004468, Accuracy = 0.5826666951179504
# PERFORMANCE ON TEST SET: Batch Loss = 1.0414049625396729, Accuracy = 0.6023074388504028
# Training iter #1020000:   Batch Loss = 1.009670, Accuracy = 0.6106666922569275
# PERFORMANCE ON TEST SET: Batch Loss = 1.0292314291000366, Accuracy = 0.6063793897628784
# Training iter #1050000:   Batch Loss = 1.024550, Accuracy = 0.6386666893959045
# PERFORMANCE ON TEST SET: Batch Loss = 1.0314593315124512, Accuracy = 0.6033254265785217
# Training iter #1080000:   Batch Loss = 0.937564, Accuracy = 0.6200000047683716
# PERFORMANCE ON TEST SET: Batch Loss = 1.0139708518981934, Accuracy = 0.5948421955108643
# Training iter #1110000:   Batch Loss = 0.915743, Accuracy = 0.6179999709129333
# PERFORMANCE ON TEST SET: Batch Loss = 1.0154099464416504, Accuracy = 0.6172378659248352
# Training iter #1140000:   Batch Loss = 0.886579, Accuracy = 0.6359999775886536
# PERFORMANCE ON TEST SET: Batch Loss = 1.0473273992538452, Accuracy = 0.607058048248291
# Training iter #1170000:   Batch Loss = 0.821953, Accuracy = 0.6813333630561829
# PERFORMANCE ON TEST SET: Batch Loss = 1.0474069118499756, Accuracy = 0.6063793897628784
# Training iter #1200000:   Batch Loss = 0.853890, Accuracy = 0.6520000100135803
# PERFORMANCE ON TEST SET: Batch Loss = 1.0236048698425293, Accuracy = 0.607058048248291
# Training iter #1230000:   Batch Loss = 0.872587, Accuracy = 0.6433333158493042
# PERFORMANCE ON TEST SET: Batch Loss = 1.0093553066253662, Accuracy = 0.5999321341514587
# Training iter #1260000:   Batch Loss = 0.897964, Accuracy = 0.6173333525657654
# PERFORMANCE ON TEST SET: Batch Loss = 1.0363850593566895, Accuracy = 0.5985748171806335
# Training iter #1290000:   Batch Loss = 0.908124, Accuracy = 0.653333306312561
# PERFORMANCE ON TEST SET: Batch Loss = 1.021545171737671, Accuracy = 0.5955208539962769
# Training iter #1320000:   Batch Loss = 1.013829, Accuracy = 0.6079999804496765
# PERFORMANCE ON TEST SET: Batch Loss = 1.1168123483657837, Accuracy = 0.5809297561645508
# Training iter #1350000:   Batch Loss = 0.953680, Accuracy = 0.5746666789054871
# PERFORMANCE ON TEST SET: Batch Loss = 1.0195554494857788, Accuracy = 0.5809297561645508
# Training iter #1380000:   Batch Loss = 0.966140, Accuracy = 0.5720000267028809
# PERFORMANCE ON TEST SET: Batch Loss = 1.0052571296691895, Accuracy = 0.582287073135376
# Training iter #1410000:   Batch Loss = 0.915238, Accuracy = 0.668666660785675
# PERFORMANCE ON TEST SET: Batch Loss = 1.0271062850952148, Accuracy = 0.626060426235199
# Training iter #1440000:   Batch Loss = 1.050172, Accuracy = 0.6039999723434448
# PERFORMANCE ON TEST SET: Batch Loss = 1.0195822715759277, Accuracy = 0.6084153652191162
# Training iter #1470000:   Batch Loss = 0.880358, Accuracy = 0.612666666507721
# PERFORMANCE ON TEST SET: Batch Loss = 0.9970413446426392, Accuracy = 0.6240244507789612
# Training iter #1500000:   Batch Loss = 0.846721, Accuracy = 0.6740000247955322
# PERFORMANCE ON TEST SET: Batch Loss = 1.0439475774765015, Accuracy = 0.6128265857696533
# Training iter #1530000:   Batch Loss = 0.847303, Accuracy = 0.6520000100135803
# PERFORMANCE ON TEST SET: Batch Loss = 1.0183279514312744, Accuracy = 0.5873770117759705
# Training iter #1560000:   Batch Loss = 0.801986, Accuracy = 0.6626666784286499
# PERFORMANCE ON TEST SET: Batch Loss = 1.0207905769348145, Accuracy = 0.5904309749603271
# Training iter #1590000:   Batch Loss = 0.840112, Accuracy = 0.6866666674613953
# PERFORMANCE ON TEST SET: Batch Loss = 0.9802913665771484, Accuracy = 0.619273841381073
# Training iter #1620000:   Batch Loss = 0.810180, Accuracy = 0.7099999785423279
# PERFORMANCE ON TEST SET: Batch Loss = 1.0035251379013062, Accuracy = 0.6121479272842407
# Training iter #1650000:   Batch Loss = 0.857542, Accuracy = 0.6259999871253967
# PERFORMANCE ON TEST SET: Batch Loss = 0.9721993207931519, Accuracy = 0.596878170967102
# Training iter #1680000:   Batch Loss = 0.871885, Accuracy = 0.6133333444595337
# PERFORMANCE ON TEST SET: Batch Loss = 0.9791995286941528, Accuracy = 0.6352222561836243
# Training iter #1710000:   Batch Loss = 0.876648, Accuracy = 0.6499999761581421
# PERFORMANCE ON TEST SET: Batch Loss = 0.9827439785003662, Accuracy = 0.6331862807273865
# Training iter #1740000:   Batch Loss = 0.912255, Accuracy = 0.6119999885559082
# PERFORMANCE ON TEST SET: Batch Loss = 1.0305334329605103, Accuracy = 0.5894129872322083
# Training iter #1770000:   Batch Loss = 0.819762, Accuracy = 0.7179999947547913
# PERFORMANCE ON TEST SET: Batch Loss = 0.9587306976318359, Accuracy = 0.6470987200737
# Training iter #1800000:   Batch Loss = 0.869405, Accuracy = 0.6073333621025085
# PERFORMANCE ON TEST SET: Batch Loss = 1.002413034439087, Accuracy = 0.5992534756660461
# Training iter #1830000:   Batch Loss = 0.860720, Accuracy = 0.6053333282470703
# PERFORMANCE ON TEST SET: Batch Loss = 0.9598857164382935, Accuracy = 0.600271463394165
# Training iter #1860000:   Batch Loss = 0.818081, Accuracy = 0.6793333292007446
# PERFORMANCE ON TEST SET: Batch Loss = 0.9960489273071289, Accuracy = 0.6318289637565613
# Training iter #1890000:   Batch Loss = 0.743216, Accuracy = 0.6826666593551636
# PERFORMANCE ON TEST SET: Batch Loss = 0.9588640928268433, Accuracy = 0.6355615854263306
# Training iter #1920000:   Batch Loss = 0.759650, Accuracy = 0.6693333387374878
# PERFORMANCE ON TEST SET: Batch Loss = 0.9566516876220703, Accuracy = 0.5965388417243958
# Training iter #1950000:   Batch Loss = 0.805512, Accuracy = 0.6653333306312561
# PERFORMANCE ON TEST SET: Batch Loss = 1.0062838792800903, Accuracy = 0.5873770117759705
# Training iter #1980000:   Batch Loss = 0.793960, Accuracy = 0.6859999895095825
# PERFORMANCE ON TEST SET: Batch Loss = 0.9473434686660767, Accuracy = 0.6199524998664856
# Training iter #2010000:   Batch Loss = 0.796010, Accuracy = 0.6473333239555359
# PERFORMANCE ON TEST SET: Batch Loss = 0.9562573432922363, Accuracy = 0.6016287803649902
# Training iter #2040000:   Batch Loss = 0.804600, Accuracy = 0.6133333444595337
# PERFORMANCE ON TEST SET: Batch Loss = 0.9490289688110352, Accuracy = 0.6012894511222839
# Training iter #2070000:   Batch Loss = 0.884504, Accuracy = 0.5926666855812073
# PERFORMANCE ON TEST SET: Batch Loss = 0.9561868906021118, Accuracy = 0.6026467680931091
# Training iter #2100000:   Batch Loss = 0.848749, Accuracy = 0.6173333525657654
# PERFORMANCE ON TEST SET: Batch Loss = 0.9761308431625366, Accuracy = 0.5829657316207886
# Training iter #2130000:   Batch Loss = 0.850129, Accuracy = 0.6320000290870667
# PERFORMANCE ON TEST SET: Batch Loss = 0.9683912992477417, Accuracy = 0.6077367067337036
# Training iter #2160000:   Batch Loss = 0.806793, Accuracy = 0.671999990940094
# PERFORMANCE ON TEST SET: Batch Loss = 0.9928275942802429, Accuracy = 0.5934848785400391
# Training iter #2190000:   Batch Loss = 1.007142, Accuracy = 0.5946666598320007
# PERFORMANCE ON TEST SET: Batch Loss = 0.9499298334121704, Accuracy = 0.5995928049087524
# Optimization Finished!
# FINAL RESULT: Batch Loss = 0.9608904123306274, Accuracy = 0.5989141464233398

# %%
# %matplotlib inline

font = {
    'family' : 'Bitstream Vera Sans',
    'weight': 'bold',
    'size' : 18
}
matplotlib.rc('font', **font)

width = 12
height = 12
plt.figure(figsize=(width,height))

indep_train_axis = np.array(range(batch_size, (len(train_losses)+1)*batch_size, batch_size))
plt.plot(indep_train_axis, np.array(train_losses), "b--", label="Train losses")
plt.plot(indep_train_axis, np.array(train_accuracies), "g--", label="Train accuracies")
indep_test_axis = np.append(
    np.array(range(batch_size, len(test_losses)*display_iter, display_iter)[:-1]),
    [training_iters]
)
plt.plot(indep_test_axis, np.array(test_losses), "b-", label="Test losses")
plt.plot(indep_test_axis, np.array(test_accuracies), "g-", label="Test accuracies")

plt.title("Training session's progress over iterations")
plt.legend(loc='upper right', shadow=True)
plt.ylabel('Training Progress (Loss or Accuracy values)')
plt.xlabel('Training iteration')

plt.show()
# Out:
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Bitstream Vera Sans'] not found. Falling back to DejaVu Sans.

# %%
predictions = one_hot_predictions.argmax(1)

print("Testing Accuracy: {}%".format(100*accuracy))

print("")
print("Precision: {}%".format(100*metrics.precision_score(y_test, predictions, average="weighted")))
print("Recall: {}%".format(100*metrics.recall_score(y_test, predictions, average="weighted")))
print("f1_score: {}%".format(100*metrics.f1_score(y_test, predictions, average="weighted")))

print("")
print("Confusion Matrix:")
confusion_matrix = metrics.confusion_matrix(y_test, predictions)
print(confusion_matrix)
normalised_confusion_matrix = np.array(confusion_matrix, dtype=np.float32)/np.sum(confusion_matrix)*100

print("")
print("Confusion matrix (normalised to % of total test data):")
print(normalised_confusion_matrix)
print("Note: training and testing data is not equally distributed amongst classes, ")
print("so it is normal that more than a 6th of the data is correctly classifier in the last category.")

width = 12
height = 12
plt.figure(figsize=(width, height))
plt.imshow(
    normalised_confusion_matrix, 
    interpolation='nearest', 
    cmap=plt.cm.rainbow
)
plt.title("Confusion matrix \n(normalised to % of total test data)")
plt.colorbar()
tick_marks = np.arange(n_classes)
plt.xticks(tick_marks, LABELS, rotation=90)
plt.yticks(tick_marks, LABELS)
plt.tight_layout()
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# Testing Accuracy: 59.891414642333984%
#
# Precision: 47.87377905386497%
# Recall: 59.89141499830336%
# f1_score: 50.93317174417508%
#
# Confusion Matrix:
# [[480  16   0   0   0   0]
#  [ 49 385  37   0   0   0]
#  [  8  49 363   0   0   0]
#  [  1   1   0   0   0 489]
#  [  0   0   0   0   0 532]
#  [  0   0   0   0   0 537]]
#
# Confusion matrix (normalised to % of total test data):
# [[16.28775     0.542925    0.          0.          0.          0.        ]
#  [ 1.6627079  13.064133    1.2555141   0.          0.          0.        ]
#  [ 0.2714625   1.6627079  12.317612    0.          0.          0.        ]
#  [ 0.03393281  0.03393281  0.          0.          0.         16.593145  ]
#  [ 0.          0.          0.          0.          0.         18.052256  ]
#  [ 0.          0.          0.          0.          0.         18.22192   ]]
# Note: training and testing data is not equally distributed amongst classes,
# so it is normal that more than a 6th of the data is correctly classifier in the last category.
# /Users/Ashu/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /Users/Ashu/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
